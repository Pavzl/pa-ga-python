# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# set the plots to display in the Jupyter notebook
# %matplotlib inline

# %%
# 9.1 Line Plot

# A. Make a dataframe called foot using the "./international_football_results.csv" file
#    Perform a few exploratory data analysis operations before working with the data set

# We'll use the .to_datetime method and .dt.year property to set the "year" column from a string to an integer

data_frame = pd.read_csv("international_football_results.csv")

data_frame["date"] = pd.to_datetime(data_frame["date"]).dt.year

data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39669 entries, 0 to 39668
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        39669 non-null  int64
#  1   home_team   39669 non-null  object
#  2   away_team   39669 non-null  object
#  3   home_score  39669 non-null  int64
#  4   away_score  39669 non-null  int64
#  5   tournament  39669 non-null  object
#  6   city        39669 non-null  object
#  7   country     39669 non-null  object
#  8   neutral     39669 non-null  bool
# dtypes: bool(1), int64(3), object(5)
# memory usage: 2.5+ MB

# %%
# B. Let's chart how many games occurred in each year:

data_frame["date"].value_counts()
# Out:
# 2008    1087
# 2011    1077
# 2004    1059
# 2000    1022
# 2001    1014
#         ...
# 1878       2
# 1874       1
# 1873       1
# 1875       1
# 1872       1
# Name: date, Length: 147, dtype: int64

# %%
# The years are out of order! Fortunately, we can sort our column by its index with sort_index()

data_frame = data_frame.set_index("date", append=True).sort_index()

data_frame
# Out:
#            home_team away_team  home_score  away_score      tournament  \
#       date
# 0     1872  Scotland   England           0           0        Friendly
# 1     1873   England  Scotland           4           2        Friendly
# 2     1874  Scotland   England           2           1        Friendly
# 3     1875   England  Scotland           2           2        Friendly
# 4     1876  Scotland   England           3           0        Friendly
# ...              ...       ...         ...         ...             ...
# 39664 2018   Uruguay    France           0           2  FIFA World Cup
# 39665 2018    Brazil   Belgium           1           2  FIFA World Cup
# 39666 2018    Sweden   England           0           2  FIFA World Cup
# 39667 2018    Russia   Croatia           2           2  FIFA World Cup
# 39668 2018    France   Belgium           1           0  FIFA World Cup
#
#                        city   country  neutral
#       date
# 0     1872          Glasgow  Scotland    False
# 1     1873           London   England    False
# 2     1874          Glasgow  Scotland    False
# 3     1875           London   England    False
# 4     1876          Glasgow  Scotland    False
# ...                     ...       ...      ...
# 39664 2018  Nizhny Novgorod    Russia     True
# 39665 2018            Kazan    Russia     True
# 39666 2018           Samara    Russia     True
# 39667 2018            Sochi    Russia    False
# 39668 2018   St. Petersburg    Russia     True
#
# [39669 rows x 8 columns]

# %%
# Finally, we're ready to plot the change over time with .plot()

data_frame.plot.line("date", "home_score")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pavel\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\pavel\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\pavel\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\pavel\pyth-15\week-6\HM Data Visualization.ipynb Cell 5 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/pavel/pyth-15/week-6/HM%20Data%20Visualization.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # Finally, we're ready to plot the change over time with .plot()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pavel/pyth-15/week-6/HM%20Data%20Visualization.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> data_frame.plot.line("date", "home_score")
#
# File c:\Users\pavel\anaconda3\lib\site-packages\pandas\plotting\_core.py:1041, in PlotAccessor.line(self, x, y, **kwargs)
#     976 @Appender(
#     977     """
#     978     See Also
#    (...)
#    1033 @Appender(_bar_or_line_doc)
#    1034 def line(self, x=None, y=None, **kwargs):
#    1035     """
#    1036     Plot Series or DataFrame as lines.
#    1037
#    1038     This function is useful to plot lines using DataFrame's values
#    1039     as coordinates.
#    1040     """
# -> 1041     return self(kind="line", x=x, y=y, **kwargs)
#
# File c:\Users\pavel\anaconda3\lib\site-packages\pandas\plotting\_core.py:937, in PlotAccessor.__call__(self, *args, **kwargs)
#     935 if is_integer(x) and not data.columns.holds_integer():
#     936     x = data_cols[x]
# --> 937 elif not isinstance(data[x], ABCSeries):
#     938     raise ValueError("x must be a label or position")
#     939 data = data.set_index(x)
#
# File c:\Users\pavel\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\pavel\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'date'

# %%
# 9.2 Bar Charts
# A. Let's see how many games each country played, represented as a bar chart

data_frame_2 = pd.read_csv("international_football_results.csv")

data_frame_2.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
# B. Now let's plot the occurence of specific scores for the home team

fig, ax = plt.subplots(figsize=(10, 5))
grouped_data = data_frame_2.groupby("home_team")
grouped_data.plot(ax = ax, kind = 'bar')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\pavel\pyth-15\week-6\HM Data Visualization.ipynb Cell 7 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/pavel/pyth-15/week-6/HM%20Data%20Visualization.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> fig, ax = plt.subplots(figsize=(10, 5))
#       <a href='vscode-notebook-cell:/c%3A/Users/pavel/pyth-15/week-6/HM%20Data%20Visualization.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> grouped_data = data_frame_2.groupby("home_team")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pavel/pyth-15/week-6/HM%20Data%20Visualization.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> grouped_data.plot(ax = ax, kind = 'bar')
#
# File c:\Users\pavel\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:543, in GroupByPlot.__call__(self, *args, **kwargs)
#     540     return self.plot(*args, **kwargs)
#     542 f.__name__ = "plot"
# --> 543 return self._groupby.apply(f)
#
# File c:\Users\pavel\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1414, in GroupBy.apply(self, func, *args, **kwargs)
#    1412 with option_context("mode.chained_assignment", None):
#    1413     try:
# -> 1414         result = self._python_apply_general(f, self._selected_obj)
#    1415     except TypeError:
#    1416         # gh-20949
#    1417         # try again, with .apply acting as a filtering
#    (...)
#    1421         # fails on *some* columns, e.g. a numeric operation
#    1422         # on a string grouper column
#    1424         with self._group_selection_context():
#
# File c:\Users\pavel\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1455, in GroupBy._python_apply_general(self, f, data, not_indexed_same)
#    1429 @final
#    1430 def _python_apply_general(
#    1431     self,
#    (...)
#    1434     not_indexed_same: bool | None = None,
#    1435 ) -> DataFrame | Series:
#    1436     """
#    1437     Apply function f in python space
#    1438
#    (...)
#    1453         data after applying f
#    1454     """
# -> 1455     values, mutated = self.grouper.apply(f, data, self.axis)
#    1457     if not_indexed_same is None:
#    1458         not_indexed_same = mutated or self.mutated
#
# File c:\Users\pavel\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:761, in BaseGrouper.apply(self, f, data, axis)
#     759 # group might be modified
#     760 group_axes = group.axes
# --> 761 res = f(group)
#     762 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     763     mutated = True
#
# File c:\Users\pavel\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:540, in GroupByPlot.__call__.<locals>.f(self)
#     539 def f(self):
# --> 540     return self.plot(*args, **kwargs)
#
# File c:\Users\pavel\anaconda3\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\pavel\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\pavel\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:332, in MPLPlot.generate(self)
#     330 self._add_table()
#     331 self._make_legend()
# --> 332 self._adorn_subplots()
#     334 for ax in self.axes:
#     335     self._post_plot_logic_common(ax, self.data)
#
# File c:\Users\pavel\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:578, in MPLPlot._adorn_subplots(self)
#     575     if self.ylabel is not None:
#     576         ax.set_ylabel(pprint_thing(self.ylabel))
# --> 578     ax.grid(self.grid)
#     580 if self.title:
#     581     if self.subplots:
#
# File c:\Users\pavel\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:299, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     294     warn_deprecated(
#     295         since, message=f"The {old!r} parameter of {func.__name__}() "
#     296         f"has been renamed {new!r} since Matplotlib {since}; support "
#     297         f"for the old name will be dropped %(removal)s.")
#     298     kwargs[new] = kwargs.pop(old)
# --> 299 return func(*args, **kwargs)
#
# File c:\Users\pavel\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3226, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3224 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3225 if axis in ['x', 'both']:
# -> 3226     self.xaxis.grid(visible, which=which, **kwargs)
#    3227 if axis in ['y', 'both']:
#    3228     self.yaxis.grid(visible, which=which, **kwargs)
#
# File c:\Users\pavel\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:299, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     294     warn_deprecated(
#     295         since, message=f"The {old!r} parameter of {func.__name__}() "
#     296         f"has been renamed {new!r} since Matplotlib {since}; support "
#     297         f"for the old name will be dropped %(removal)s.")
#     298     kwargs[new] = kwargs.pop(old)
# --> 299 return func(*args, **kwargs)
#
# File c:\Users\pavel\anaconda3\lib\site-packages\matplotlib\axis.py:1434, in Axis.grid(self, visible, which, **kwargs)
#    1431 if which in ['major', 'both']:
#    1432     gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1433                         if visible is None else visible)
# -> 1434     self.set_tick_params(which='major', **gridkw)
#    1435 self.stale = True
#
# File c:\Users\pavel\anaconda3\lib\site-packages\matplotlib\axis.py:874, in Axis.set_tick_params(self, which, reset, **kw)
#     872     self._major_tick_kw.update(kwtrans)
#     873     for tick in self.majorTicks:
# --> 874         tick._apply_params(**kwtrans)
#     875 if which in ['minor', 'both']:
#     876     self._minor_tick_kw.update(kwtrans)
#
# File c:\Users\pavel\anaconda3\lib\site-packages\matplotlib\axis.py:377, in Tick._apply_params(self, **kw)
#     375 if 'color' in kw:
#     376     tick_kw['markeredgecolor'] = kw['color']
# --> 377 self.tick1line.set(**tick_kw)
#     378 self.tick2line.set(**tick_kw)
#     379 for k, v in tick_kw.items():
#
# File c:\Users\pavel\anaconda3\lib\site-packages\matplotlib\artist.py:116, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     108 if not hasattr(cls.set, '_autogenerated_signature'):
#     109     # Don't overwrite cls.set if the subclass or one of its parents
#     110     # has defined a set method set itself.
#     111     # If there was no explicit definition, cls.set is inherited from
#     112     # the hierarchy of auto-generated set methods, which hold the
#     113     # flag _autogenerated_signature.
#     114     return
# --> 116 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     117 cls.set.__name__ = "set"
#     118 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File c:\Users\pavel\anaconda3\lib\site-packages\matplotlib\artist.py:1163, in Artist.set(self, **kwargs)
#    1159 def set(self, **kwargs):
#    1160     # docstring and signature are auto-generated via
#    1161     # Artist._update_set_signature_and_docstring() at the end of the
#    1162     # module.
# -> 1163     kwargs = cbook.normalize_kwargs(kwargs, self)
#    1164     return self.update(kwargs)
#
# KeyboardInterrupt:

# %%
# C. Instead of sorting from highest to lowest value, let's sort the x axis in ascending order

# %%
# BONUS: Compare the home_score and away_score value counts to analyze home field advantage
# You will need to use the .apply method to use value_counts on each column of a dataframe

# %%
# 9.3 Histograms
# A. Let's start with a new dataset. Create a dataframe called choc from the './chocolate_reviews.csv' file
#    Inspect the data using some exploratory data analysis methods

# %%
# B. Now, let's explore the distribution of ratings
#    i. Start by plotting the Rating column in a histogram

# %%
#    ii. Looking good! Let's see how granular we can get
#        Modify the number of bins to change how ranges are distributed

# %%
#    iii. Now, let's add some descriptive labels to our chart using matplotlib

# %%
# 9.4 Scatter Plots
# A. Is there a connection between Review Date and Rating? Plot them with a scatter plot

# Why is this graph not so helpful?

# %%
# B. Explore this new dataframe, then scatter plot correlation between Total Volume and AveragePrice

# %%
# 9.5 Visualizations to Hypotheses
# Create visualizations around any of the above datasets or our superstore datasets
# For at least one of the visualizations, attach a hypothesis or specific claim the chart supports
